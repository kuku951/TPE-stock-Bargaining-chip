# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("d:\\stock\\0809\\031068.csv",encoding="utf-8",header=2)#heaer2是從第二列開始跑

# %%
df
# Out:
#      序號          券商    價格    買進股數    賣出股數  Unnamed: 5   序號.1        券商.1  \
# 0     1    1042臺銀臺南  0.18    2000       0         NaN    2.0    111E企銀桃園
# 1     3    111E企銀桃園  0.19       0   17000         NaN    4.0    1167日盛嘉義
# 2     5    116j日盛頭份  0.19   10000       0         NaN    6.0    116Z日盛中和
# 3     7    5858統一嘉義  0.21       0    5000         NaN    8.0    592G元富新竹
# 4     9    592X元富草屯  0.18    3000       0         NaN   10.0    6160中國信託
# 5    11    6160中國信託  0.19       0   50000         NaN   12.0    6162中信託忠
# 6    13    6381光和溪湖  0.18   50000       0         NaN   14.0    700W兆豐城中
# 7    15    700X兆豐永和  0.20       0   50000         NaN   16.0  8150台    新
# 8    17  8150台    新  0.20       0   10000         NaN   18.0    8151台新建北
# 9    19    8159台新台南  0.19       0   50000         NaN   20.0    815B台新台中
# 10   21    815B台新台中  0.22       0   10000         NaN   22.0  8560新    光
# 11   23  8560新    光  0.19   20000       0         NaN   24.0  8560新    光
# ...

# %%
df1=df.drop(["Unnamed: 5"], axis=1)#刪除欄位

# %%
df2=df1[['序號.1','券商.1','價格.1','買進股數.1','賣出股數.1']]
df2.columns = ['序號','券商','價格','買進股數','賣出股數']
df2
# Out:
#        序號          券商    價格      買進股數     賣出股數
# 0     2.0    111E企銀桃園  0.18       0.0    7000
# 1     4.0    1167日盛嘉義  0.19    1000.0       0
# 2     6.0    116Z日盛中和  0.20   50000.0       0
# 3     8.0    592G元富新竹  0.19       0.0  100000
# 4    10.0    6160中國信託  0.17   10000.0       0
# 5    12.0    6162中信託忠  0.19   60000.0       0
# 6    14.0    700W兆豐城中  0.19   20000.0       0
# 7    16.0  8150台    新  0.18       0.0    5000
# 8    18.0    8151台新建北  0.19   20000.0       0
# 9    20.0    815B台新台中  0.21   10000.0       0
# 10   22.0  8560新    光  0.17       0.0   10000
# 11   24.0  8560新    光  0.20   20000.0       0
# 12   26.0    8842玉山新莊  0.19   20000.0       0
# 13   28.0    884C玉山南京  0.18   30000.0       0
# 14   30.0    8881國泰高雄  0.20    2000.0       0
# 15   32.0    8882國泰台中  0.19       0.0   50000
# 16   34.0    8884國泰台南  0.17   20000.0       0
# 17   36.0    8884國泰台南  0.19   10000.0       0
# 18   38.0    8886國泰新莊  0.20       0.0   50000
# ...

# %%
df3=df1[['序號','券商','價格','買進股數','賣出股數']]
df3
# Out:
#      序號          券商    價格    買進股數    賣出股數
# 0     1    1042臺銀臺南  0.18    2000       0
# 1     3    111E企銀桃園  0.19       0   17000
# 2     5    116j日盛頭份  0.19   10000       0
# 3     7    5858統一嘉義  0.21       0    5000
# 4     9    592X元富草屯  0.18    3000       0
# 5    11    6160中國信託  0.19       0   50000
# 6    13    6381光和溪湖  0.18   50000       0
# 7    15    700X兆豐永和  0.20       0   50000
# 8    17  8150台    新  0.20       0   10000
# 9    19    8159台新台南  0.19       0   50000
# 10   21    815B台新台中  0.22       0   10000
# 11   23  8560新    光  0.19   20000       0
# 12   25  8840玉    山  0.20  100000       0
# 13   27    884A玉山士林  0.19   11000       0
# 14   29    8881國泰高雄  0.19    8000       0
# 15   31    8881國泰高雄  0.21    1000       0
# 16   33    8882國泰台中  0.20  100000       0
# 17   35    8884國泰台南  0.18   10000       0
# 18   37    8885國泰桃園  0.20       0   20000
# 19   39    8888國泰敦南  0.18   55000       0
# 20   41    8888國泰敦南  0.20   18000       0
# ...

# %%
df4 = df2.append(df3).sort_values(by=['序號'])
df4
# Out:
#        序號        券商    價格     買進股數     賣出股數
# 0     1.0  1042臺銀臺南  0.18   2000.0        0
# 0     2.0  111E企銀桃園  0.18      0.0    7000
# 1     3.0  111E企銀桃園  0.19      0.0    17000
# 1     4.0  1167日盛嘉義  0.19   1000.0       0
# 2     5.0  116j日盛頭份  0.19  10000.0        0
# ..    ...       ...   ...      ...      ...
# 50  102.0  9A9B永豐中和  0.20      0.0  150000
# 51  103.0  9A9D永豐忠孝  0.18      0.0    10000
# 51  104.0  9A9f永豐中盛  0.19  23000.0       0
# 52  105.0  9A9f永豐中盛  0.21      0.0    10000
# 52    NaN       NaN   NaN      NaN
#
# [106 rows x 5 columns]

# %%
a=df4['券商'] == '9636富邦中壢'
df0=df4[a]#a=true抓取券商==true
#df4[a].to_csv("c:/Users/User/Desktop/stock/合庫.csv") #相对位置，保存在getwcd()获得的路径下
#str=df0.iat[0,1]
df0[["券商","價格","買進股數","賣出股數"]]
# Out:
#           券商    價格      買進股數    賣出股數
# 31  9636富邦中壢  0.19  140000.0  30000
# 32  9636富邦中壢  0.20   20000.0       0
# 32  9636富邦中壢  0.21   45000.0  50000
# 33  9636富邦中壢  0.22   10000.0       0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(len(df0.價格))
width = 0.3
plt.bar(x-0.05,df0.買進股數,0.1, color='red',label='buy')#x-0.1座標點左右，width長棒的寬度
df0["賣出股數"] = df0["賣出股數"].astype(float)
print(df0.賣出股數)
plt.bar(x+0.05,df0.賣出股數,0.1,label='sell', color='green')
#plt.title(str+'buy/sell')
plt.xticks(x,df0.價格)
plt.xlabel("Price")
plt.ylabel("Share")
plt.title("9636")
plt.legend(loc='upper right')
plt.show()

#plt.bar(df0.買進股數)
#plt.hist(df0.賣出股數)
# Out:
# 31    30000.0
# 32        0.0
# 32    50000.0
# 33        0.0
# Name: 賣出股數, dtype: float64
# <ipython-input-92-7c912da64840>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df0["賣出股數"] = df0["賣出股數"].astype(float)
